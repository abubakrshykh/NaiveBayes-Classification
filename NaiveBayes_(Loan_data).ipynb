# %%
import numpy as np 
import pandas as pd

# %%
#MOUNT GOOGLE DRIVE INTO COLAB
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#LOAD DATA INTO PANDAS
dataset = pd.read_csv('/content/drive/My Drive/Datasets/Datasets/loan_data.csv')

# %%
#CHECKING THE OVERALL QUALITY OF DATA
dataset
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
#EXPLORING THIS CATEGORICAL FEATURE
dataset['purpose'].unique()
# Out:
# array(['debt_consolidation', 'credit_card', 'all_other',
#        'home_improvement', 'small_business', 'major_purchase',
#        'educational'], dtype=object)

# %%
#CHANGING THIS FEATURE TO NUMERICAL CATEGORIES
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset['purpose'] = le.fit_transform(dataset['purpose'])

# %%
#CLEANED DATASET
dataset
# Out:
#       credit.policy  purpose  int.rate  installment  log.annual.inc    dti  \
# 0                 1        2    0.1189       829.10       11.350407  19.48
# 1                 1        1    0.1071       228.22       11.082143  14.29
# 2                 1        2    0.1357       366.86       10.373491  11.63
# 3                 1        2    0.1008       162.34       11.350407   8.10
# 4                 1        1    0.1426       102.92       11.299732  14.97
# ...             ...      ...       ...          ...             ...    ...
# 9573              0        0    0.1461       344.76       12.180755  10.39
# 9574              0        0    0.1253       257.70       11.141862   0.21
# 9575              0        2    0.1071        97.81       10.596635  13.09
# 9576              0        4    0.1600       351.58       10.819778  19.18
# 9577              0        2    0.1392       853.43       11.264464  16.28
#
# ...

# %%
#CHECKING FOR ANY NULL VALUES
dataset.isna().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
#ASSIGNING THE DEPENDENT AND INDEPENDENT VARIABLES
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
#SPLITING THE DATASET
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
#IMPORTING THE NAIVE BAYES CLASSIFICATION MODEL
from sklearn.naive_bayes import BernoulliNB
model = BernoulliNB()
model.fit(X_train, y_train)
# Out:
# BernoulliNB()

# %%
#CHECKING THE ACCURACY ON TEST DATASET
from sklearn.metrics import accuracy_score
acc = accuracy_score(model.predict(X_test), y_test)
acc
# Out:
# 0.83785664578984

# %%
#CHECKING THE ACCURACY ON TRAIN DATSET
from sklearn.metrics import accuracy_score
acc = accuracy_score(model.predict(X_train), y_train)
acc
# Out:
# 0.8406921241050119
